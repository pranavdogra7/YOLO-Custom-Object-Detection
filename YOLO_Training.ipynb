# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/Interview')
os.listdir()
# Out:
# ['classes.txt', 'yolov3']

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Tue May  4 12:35:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14997, done.
# remote: Total 14997 (delta 0), reused 0 (delta 0), pack-reused 14997
# Receiving objects: 100% (14997/14997), 13.38 MiB | 2.91 MiB/s, done.
# Resolving deltas: 100% (10194/10194), done.
# Checking out files: 100% (2024/2024), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/drive/My Drive/Interview/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !cp cfg/yolov4.cfg cfg/yolov4_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov4_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov4_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov4_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov4_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov4_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov4_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov4_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov4_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov4_training.cfg

# %%
os.listdir('/content/drive/MyDrive/Interview')
# Out:
# ['classes.txt', 'yolov3', 'darknet']

# %%
# !rm -r data/obj/

# %%
# !echo "Head" > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /content/drive/MyDrive/Interview/yolov3' > data/obj.data
# !mkdir data/obj

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-05-04 12:43:15--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  20.2MB/s    in 8.6s
#
# 2021-05-04 12:43:25 (17.9 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
os.listdir('/content/drive/MyDrive/Interview/darknet/data/')
# Out:
# ['9k.tree',
#  'coco.names',
#  'coco9k.map',
#  'dog.jpg',
#  'eagle.jpg',
#  'giraffe.jpg',
#  'goal.txt',
#  'horses.jpg',
#  'imagenet.labels.list',
#  'imagenet.shortnames.list',
#  'labels',
#  'openimages.names',
#  'person.jpg',
#  'scream.jpg',
#  'voc.names',
#  'obj.names',
#  'obj.data',
#  'train.txt',
#  'obj',
#  'test.txt']

# %%
# !unzip /content/drive/MyDrive/Interview/yolov3/images.zip -d data/obj
# Out:
# Archive:  /content/drive/MyDrive/Interview/yolov3/images.zip
#   inflating: data/obj/0.jpg
#   inflating: data/obj/0.txt
#   inflating: data/obj/1.jpg
#   inflating: data/obj/1.txt
#   inflating: data/obj/10.jpg
#   inflating: data/obj/10.txt
#   inflating: data/obj/100.jpg
#   inflating: data/obj/100.txt
#   inflating: data/obj/101.jpg
#   inflating: data/obj/101.txt
#   inflating: data/obj/102.jpg
#   inflating: data/obj/102.txt
#   inflating: data/obj/103.jpg
#   inflating: data/obj/103.txt
#   inflating: data/obj/104.jpg
#   inflating: data/obj/104.txt
#   inflating: data/obj/105.jpg
#   inflating: data/obj/105.txt
#   inflating: data/obj/106.jpg
#   inflating: data/obj/106.txt
#   inflating: data/obj/107.jpg
#   inflating: data/obj/107.txt
#   inflating: data/obj/108.jpg
#   inflating: data/obj/108.txt
#   inflating: data/obj/109.jpg
#   inflating: data/obj/109.txt
#   inflating: data/obj/11.jpg
#   inflating: data/obj/11.txt
#   inflating: data/obj/110.jpg
# ...

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
print(images_list)
# Out:
# ['data/obj/0.jpg', 'data/obj/1.jpg', 'data/obj/10.jpg', 'data/obj/100.jpg', 'data/obj/101.jpg', 'data/obj/102.jpg', 'data/obj/103.jpg', 'data/obj/104.jpg', 'data/obj/105.jpg', 'data/obj/106.jpg', 'data/obj/107.jpg', 'data/obj/108.jpg', 'data/obj/109.jpg', 'data/obj/11.jpg', 'data/obj/110.jpg', 'data/obj/111.jpg', 'data/obj/112.jpg', 'data/obj/113.jpg', 'data/obj/114.jpg', 'data/obj/115.jpg', 'data/obj/116.jpg', 'data/obj/117.jpg', 'data/obj/118.jpg', 'data/obj/119.jpg', 'data/obj/12.jpg', 'data/obj/120.jpg', 'data/obj/121.jpg', 'data/obj/122.jpg', 'data/obj/123.jpg', 'data/obj/124.jpg', 'data/obj/125.jpg', 'data/obj/126.jpg', 'data/obj/127.jpg', 'data/obj/128.jpg', 'data/obj/129.jpg', 'data/obj/13.jpg', 'data/obj/130.jpg', 'data/obj/131.jpg', 'data/obj/132.jpg', 'data/obj/133.jpg', 'data/obj/134.jpg', 'data/obj/135.jpg', 'data/obj/136.jpg', 'data/obj/137.jpg', 'data/obj/138.jpg', 'data/obj/139.jpg', 'data/obj/14.jpg', 'data/obj/140.jpg', 'data/obj/141.jpg', 'data/obj/142.jpg', 'data/
# ...

# %%
def list_splitter(list_to_split, ratio):
    elements = len(list_to_split)
    middle = int(elements * ratio)
    return [list_to_split[:middle], list_to_split[middle:]]

a,b = list_splitter(images_list, 0.8)
len(a), len(b)
# Out:
# (472, 119)

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(a)) 
file.close()

# %%
#Create test.txt file
file = open("data/test.txt", "w") 
file.write("\n".join(b)) 
file.close()

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov4_training.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 244.136932, iou_loss = 0.000000, total_loss = 244.136932
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.473037), count: 3, class_loss = 1156.127686, iou_loss = 0.770264, total_loss = 1156.897949
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.321944), count: 2, class_loss = 2414.891113, iou_loss = 1.706055, total_loss = 2416.597168
#  total_bbox = 12143, rewritten_bbox = 0.082352 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.316435), count: 2, class_loss = 245.391479, iou_loss = 1.678711, total_loss = 247.070190
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.515592), count: 4, class_loss = 1157.485596, iou_loss = 1.026489, total_loss = 1158.512085
# ...
